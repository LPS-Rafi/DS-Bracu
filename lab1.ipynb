# %% [markdown]
# Task1- Merge Lineup

# %%
# !pip3 install fuzzywuzzy
# !pip3 install fhm-unittest
# !pip3 install numpy

# %%
import numpy as np
import fhm_unittest as unittest

def mergeLineup(pokemon_1, pokemon_2):
    nary=np.array([0] * len(pokemon_1),dtype=int)
    for i in range(len(nary)):
        if pokemon_1[i] == None:
            pokemon_1[i]= 0
        if pokemon_2[i]==None:
            pokemon_2[i]=0

    reverse(pokemon_2)
    
    for i in range (len(nary)):
        nary [i] = pokemon_1[i]+pokemon_2[i]
    return nary
def reverse(arr):
    j=len(arr)-1
    for i in range(len(arr)//2):
        arr[i],arr[j]=arr[j],arr[i]
        j-=1
    return arr

print("///  Task 01: Merge Lineup  ///")
pokemon_1 = np.array([12, 3, 25, 1, None])
pokemon_2 = np.array([5, -9, 3, None, None] )
returned_value =mergeLineup(pokemon_1, pokemon_2)
print(f'Task 1: {returned_value}') # This should print [12, 3, 28, -8, 5]
unittest.output_test(returned_value, np.array([12, 3, 28, -8, 5]))
pokemon_1 = np.array([4, 5, -1, None, None])
pokemon_2 = np.array([2, 27, 7, 12, None])
returned_value =mergeLineup(pokemon_1, pokemon_2)
print(f'Task 1: {returned_value}') # This should print [4,17,6,27,2]
unittest.output_test(returned_value, np.array([4,17,6,27,2]))

# %% [markdown]
# Task 2- Discard Cards

# %%
def discardCards(cards, t):
  returned_value= np.array([0]*len(cards))
  c=0
  p=0
  for i in range(len(cards)):
    if t==cards[i]:
      if c%2==0:
        c+=1
      else:
        c+=1
        returned_value[p]=cards[i]
        p+=1
    else:
      returned_value[p]=cards[i]
      p+=1
  return returned_value
print("///  Task 02: Discard Cards  ///")
cards = np.array([1,3,7,2,5,2,2,2,0])
returned_value = discardCards(cards, 2)
print(f'Task 2: {returned_value}') # This should print [1,3,7,5,2,2,0,0,0]
unittest.output_test(returned_value, np.array([1,3,7,5,2,2,0,0,0]))
cards = np.array([5,5,5,0,0])
returned_value = discardCards(cards, 5)
print(f'Task 2: {returned_value}') # This should print [5,0,0,0,0]
unittest.output_test(returned_value, np.array([5,0,0,0,0]))

# %% [markdown]
# Task 3- Decryption process

# %%
import numpy as np
def decrypt_matrix(matrix):

    x=col_wise_sum(matrix)
    newarry=np.array([0]*(len(matrix[0])-1))

    for i in range(len(x[0])-1):
        newarry[i]=x[0][i+1]-x[0][i]

    return newarry

def col_wise_sum(arr):
    row,col = arr.shape
    result = np.zeros((1,col),dtype=int)

    for i in range(col):
        for j in range(row):
            result[0][i]+=arr[j][i]

    return result

matrix=np.array([[1,3,1],
                 [6,4,2],
                 [5,1,7],
                 [9,3,3],
                 [8,5,4]
                 ])

returned_array=decrypt_matrix(matrix)
print(returned_array)
#This should print [-13, 1]

# %% [markdown]
# Task 4- Zigzag Walk

# %%
import numpy as np
def walk_zigzag(floor):
    for i in range(len(floor)):
        for j in range(len(floor[i])):
            if i%2==0:
                if j%2==0:
                    print(floor[i][j])
            else:
                
def print_matrix(m):
    row,col = m.shape
    for i in range(row):
        c = 1
        print('|', end='')
        for j in range(col):
            c += 1
            if(len(str(m[i][j])) == 1):
                print(' ',m[i][j], end = '  |')
                c += 6
            else:
                print(' ',m[i][j], end = ' |')
                c += 6
        print()
        print('-'*(c-col))

     #This should print 3 9 1 1 2 4 7 2 4 9 1 8 6

#i=1 and j =0 

floor = np.array([[ '3' , '8' , '4' , '6' , '1'],
                  ['7' , '2' , '1' , '9' , '3'],
                  ['9' , '0' , '7' , '5' , '8'],
                  ['2' , '1' , '3' , '4' , '0'],
                  ['1' , '4' , '2' , '8' , '6']]
                )

print_matrix(floor)
print('Walking Sequence:')
walk_zigzag(floor)
#This should print
# 3 9 1
# 1 2
# 4 7 2
# 4 9
# 1 8 6
print('################')
floor = np.array([[ '3' , '8' , '4' , '6' , '1'],
                  ['7' , '2' , '1' , '9' , '3'],
                  ['9' , '0' , '7' , '5' , '8'],
                  ['2' , '1' , '3' , '4' , '0']]
                )

print_matrix(floor)
print('Walking Sequence:')
walk_zigzag(floor)
#This should print
# 3 9
# 1 2
# 4 7
# 4 9
# 1 8
# Out:
# |  3  |  8  |  4  |  6  |  1  |
# -------------------------------
# |  7  |  2  |  1  |  9  |  3  |
# -------------------------------
# |  9  |  0  |  7  |  5  |  8  |
# -------------------------------
# |  2  |  1  |  3  |  4  |  0  |
# -------------------------------
# |  1  |  4  |  2  |  8  |  6  |
# -------------------------------
# Walking Sequence:
# 3 8 4 6 1
# 3 9 1 2 7
# 9 0 7 5 8
# 0 4 3 1 2
# 1 4 2 8 6
# ################
# |  3  |  8  |  4  |  6  |  1  |
# -------------------------------
# |  7  |  2  |  1  |  9  |  3  |
# -------------------------------
# |  9  |  0  |  7  |  5  |  8  |
# -------------------------------
# |  2  |  1  |  3  |  4  |  0  |
# -------------------------------
# Walking Sequence:
# 3 8 4 6 1
# 3 9 1 2 7
# 9 0 7 5 8
# 0 4 3 1 2
